# %%
import pandas as pd

# %%
#Se crean los dataframes con los archivos csv's descargados de la pagina https://insideairbnb.com/get-the-data (buenos aires) 
#Datos anuales revisados cada 3 meses

#df_calendario = pd.read_csv("calendar.csv")
df_anuncios = pd.read_csv("listings.csv")
df_barrios = pd.read_csv("neighbourhoods_summary.csv")

# %%
#Determinamos el tamaño de cada dataset

print(f"El dataset calendario tiene: {df_anuncios.shape[0]} filas y  {df_anuncios.shape[1]} columnas")
print(f"El dataset calendario tiene: {df_barrios.shape[0]} filas y  {df_barrios.shape[1]} columnas")
# Out:
# El dataset calendario tiene: 27348 filas y  85 columnas
# El dataset calendario tiene: 49 filas y  2 columnas

# %%
print("****Las columnas de anuncios****")
print("\n")
for columna in df_anuncios.columns:
    print(f"{columna} ({df_anuncios[columna].dtype.name})")
print("\n")

print("****Las columnas de barrios****")
print("\n")
for columna in df_barrios.columns:
    print(f"{columna} ({df_barrios[columna].dtype.name})")
print("\n")
# Out:
# ****Las columnas de anuncios****
#
#
# id (int64)
# listing_url (object)
# scrape_id (int64)
# last_scraped (object)
# source (object)
# name (object)
# description (object)
# neighborhood_overview (float64)
# picture_url (object)
# host_id (int64)
# host_url (object)
# host_profile_id (int64)
# host_profile_url (object)
# host_name (object)
# host_since (float64)
# hosts_time_as_user_years (int64)
# hosts_time_as_user_months (int64)
# hosts_time_as_host_years (int64)
# hosts_time_as_host_months (int64)
# host_location (object)
# host_about (object)
# host_response_time (float64)
# host_response_rate (float64)
# host_acceptance_rate (float64)
# host_is_superhost (object)
# host_thumbnail_url (float64)
# host_picture_url (object)
# host_neighbourhood (float64)
# host_listings_count (int64)
# host_total_listings_count (float64)
# host_verifications (float64)
# host_has_profile_pic (object)
# host_identity_verified (object)
# neighbourhood (float64)
# neighbourhood_cleansed (object)
# ...

# %%
df_anuncios['neighbourhood_cleansed'].value_counts()
# Out:
# neighbourhood_cleansed
# Palermo              8963
# Recoleta             3828
# San Nicolas          2156
# Belgrano             1318
# Retiro               1310
# Monserrat            1256
# Balvanera            1051
# Almagro              1011
# Villa Crespo          927
# San Telmo             769
# Colegiales            604
# Nuñez                 473
# Chacarita             473
# Caballito             443
# Constitucion          372
# Puerto Madero         361
# Villa Urquiza         299
# Barracas              201
# Saavedra              179
# San Cristobal         153
# Flores                136
# Boca                  100
# Villa Del Parque      100
# Coghlan                90
# Villa Ortuzar          89
# Boedo                  86
# Parque Patricios       82
# Villa Devoto           82
# Parque Chacabuco       58
# Parque Chas            44
# Paternal               38
# Villa Pueyrredon       37
# Floresta               35
# Villa Luro             30
# ...
